# %%
from pythlete import safetycar

# %%
# run the simulation without safety car
safetycar.simulation_results(1, 'NED', 'HAM', safety_car = 0)
# Out:
# Current race standings
#    driver    gap         team  position
# 0     HAM   0.00     Mercedes         1
# 1     LEC  15.40      Ferrari         2
# 2     RUS  17.54     Mercedes         3
# 3     PER  18.69     Red Bull         4
# 4     VER  20.00     Red Bull         5
# 5     SAI  21.20      Ferrari         6
# 6     ALO  23.40       Alpine         7
# 7     OCO  28.30       Alpine         8
# 8     RIC  32.20      Mclaren         9
# 9     VET  37.50  AstonMartin        10
# 10    STR  40.20  AstonMartin        11
# 11    MSC  44.70         Haas        12
# 12    NOR  48.60      Mclaren        13
# 13    BOT  49.20   AlphaRomeo        14
# 14    MAG  50.20         Haas        15
# 15    GAS  51.20   AlphaTauri        16
# 16    ZHO  53.20   AlphaRomeo        17
# 17    TSU  56.80   AlphaTauri        18
# 18    ALB  59.80     Williams        19
# 19    LAT  70.40     Williams        20
# On Average:
# By Pitting, new position estimated will be:  6
# We lose:  5 positions
# Estimated time =  21.48
#
#
# Lower bound:
# Lower bound of 95% confidence interval:  5
# We lose:  4 positions
# New Estimated time =  20.71
#
#
# Upper bound:
# Upper bound of 95% confidence interval:  6
# We lose:  5 positions
# New Estimated time =  22.26
#    driver         team  new_gap  previous_position  new_position
# 0     LEC      Ferrari     0.00                  5             1
# 1     RUS     Mercedes     2.14                  2             2
# 2     PER     Red Bull     3.29                  3             3
# 3     VER     Red Bull     4.60                  4             4
# 4     SAI      Ferrari     5.80                  6             5
# 5     HAM     Mercedes     6.08                  1             6
# 6     ALO       Alpine     8.00                  7             7
# 7     OCO       Alpine    12.90                  8             8
# 8     RIC      Mclaren    16.80                 10             9
# 9     VET  AstonMartin    22.10                 11            10
# 10    STR  AstonMartin    24.80                 12            11
# 11    MSC         Haas    29.30                 13            12
# 12    NOR      Mclaren    33.20                  9            13
# 13    BOT   AlphaRomeo    33.80                 19            14
# 14    MAG         Haas    34.80                 14            15
# 15    GAS   AlphaTauri    35.80                 15            16
# 16    ZHO   AlphaRomeo    37.80                 20            17
# 17    TSU   AlphaTauri    41.40                 16            18
# 18    ALB     Williams    44.40                 17            19
# 19    LAT     Williams    55.00                 18            20

# %%
# run the simulation with safety car
safetycar.simulation_results(1, 'NED', 'HAM', safety_car = 1)
# Out:
# Current race standings
#    driver    gap         team  position
# 0     HAM   0.00     Mercedes         1
# 1     LEC  15.40      Ferrari         2
# 2     RUS  17.54     Mercedes         3
# 3     PER  18.69     Red Bull         4
# 4     VER  20.00     Red Bull         5
# 5     SAI  21.20      Ferrari         6
# 6     ALO  23.40       Alpine         7
# 7     OCO  28.30       Alpine         8
# 8     RIC  32.20      Mclaren         9
# 9     VET  37.50  AstonMartin        10
# 10    STR  40.20  AstonMartin        11
# 11    MSC  44.70         Haas        12
# 12    NOR  48.60      Mclaren        13
# 13    BOT  49.20   AlphaRomeo        14
# 14    MAG  50.20         Haas        15
# 15    GAS  51.20   AlphaTauri        16
# 16    ZHO  53.20   AlphaRomeo        17
# 17    TSU  56.80   AlphaTauri        18
# 18    ALB  59.80     Williams        19
# 19    LAT  70.40     Williams        20
# On Average:
# By Pitting, new position estimated will be:  1
# We lose:  0 positions
# Estimated time =  13.91
#
#
# Lower bound:
# Lower bound of 95% confidence interval:  1
# We lose:  0 positions
# New Estimated time =  13.11
#
#
# Upper bound:
# Upper bound of 95% confidence interval:  1
# We lose:  0 positions
# New Estimated time =  14.71
#    driver         team  new_gap  previous_position  new_position
# 0     HAM     Mercedes     0.00                  1             1
# 1     LEC      Ferrari     1.49                  5             2
# 2     RUS     Mercedes     3.63                  2             3
# 3     PER     Red Bull     4.78                  3             4
# 4     VER     Red Bull     6.09                  4             5
# 5     SAI      Ferrari     7.29                  6             6
# 6     ALO       Alpine     9.49                  7             7
# 7     OCO       Alpine    14.39                  8             8
# 8     RIC      Mclaren    18.29                 10             9
# 9     VET  AstonMartin    23.59                 11            10
# 10    STR  AstonMartin    26.29                 12            11
# 11    MSC         Haas    30.79                 13            12
# 12    NOR      Mclaren    34.69                  9            13
# 13    BOT   AlphaRomeo    35.29                 19            14
# 14    MAG         Haas    36.29                 14            15
# 15    GAS   AlphaTauri    37.29                 15            16
# 16    ZHO   AlphaRomeo    39.29                 20            17
# 17    TSU   AlphaTauri    42.89                 16            18
# 18    ALB     Williams    45.89                 17            19
# 19    LAT     Williams    56.49                 18            20
